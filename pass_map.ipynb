# %%
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch
import seaborn as sns

# %%
# Read in the data

df = pd.read_csv(r"C:\Users\jamie\OneDrive\Documents\Gravenberch Pass map\Gravencberch vs United.csv")

# %%
df
# Out:
#         x       y   endX    endY         Type
# 0   252.0  178.56  361.2  161.82  Unsuccesful
# 1   193.2  181.35  180.6  186.90    Succesful
# 2   285.6   83.70  302.4   13.95    Succesful
# 3   100.8  111.60   54.6   83.70    Succesful
# 4   147.0  234.60  193.2  209.25    Succesful
# 5   235.2  103.23  294.0  125.55    Succesful
# 6   235.2   75.33  277.2   30.69    Succesful
# 7   222.6  172.98  172.2  122.70    Succesful
# 8   172.2  142.29  126.0  100.44    Succesful
# 9    92.4  225.99   46.2  256.68    Succesful
# 10   88.2  106.20  142.8   89.28    Succesful
# 11  147.0  147.87   88.2   83.70    Succesful
# 12  130.2   89.28   92.4  167.40    Succesful
# 13  189.0  136.71  151.2  172.98    Succesful
# 14  260.4  237.15  226.8  267.80    Succesful
# 15  205.8  119.97  193.2  206.40    Succesful
# 16  264.6   89.28  235.2   41.85    Succesful
# 17  252.0  150.66  226.8  128.34    Succesful
# 18  134.4  159.03  189.0  164.61    Succesful
# ...

# %%
pitch = Pitch(pitch_type='wyscout', pitch_color='#000000', line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(16,11), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#000000')

pitch.draw(ax=ax)
plt.gca().invert_yaxis

for x in range(len(df['x'])):
    if df['Type'][x] == 'Succesful':
        plt.plot((df['endX'][x],df['x'][x]),(df['endY'][x],df['y'][x]),color='green')
        plt.scatter(df['x'][x],df['y'][x],color='green')
